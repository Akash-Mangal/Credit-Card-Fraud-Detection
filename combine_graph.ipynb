# %%
import matplotlib.pyplot as plt

data = {
    'Data': ['80-20', '70-30', '60-40', '40-60', '30-70', '20-80', '10-90', '5-95', 'UndSamp'],
    'Gradient': [0.982324, 0.9827267, 0.9840883, 0.9833496, 0.9849379, 0.983975351, 0.9848734, 0.9859776, 0.98162235],
    'RandomF': [0.99934, 0.9993011, 0.9992994, 0.9992201, 0.9991582, 0.999111215, 0.999022, 0.9988630, 0.98707136],
    'Decision': [0.999459, 0.9994493, 0.9994055, 0.9993087, 0.9992619, 0.99914304, 0.9989066, 0.998666, 0.9876599],
    'KNN': [0.995413, 0.9953740, 0.9951112, 0.9944883, 0.9938771, 0.99338185, 0.9925444, 0.990699, 0.9436607],
    'Logistic': [0.918202, 0.9320227, 0.9333486, 0.9310614, 0.9403511, 0.93283289, 0.9268194, 0.9223520, 0.9097211],
    'XGBoost': [0.998185, 0.9983633, 0.9982790, 0.9983162, 0.9986669, 0.99848883, 0.9985580, 0.9985658, 0.9911]
}

# Define colors for each line
colors = ['red', 'blue', 'green', 'orange', 'purple', 'violet']

# Create the figure and axis
fig, ax = plt.subplots()

# Plot the data
for i, model in enumerate(data.keys()):
    if model != 'Data':
        ax.plot(data['Data'], data[model], label=model, color=colors[i % len(colors)])

# Set the y-axis range
ax.set_ylim([0.9, 1])

# Add a legend
ax.legend()

# Add labels and title
ax.set_xlabel('Data')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy of Different Models')
# Set the background of the plot to be transparent
ax.patch.set_alpha(0)

# Set the transparency of the grid lines
ax.grid(alpha=0.2)

# Save the plot as a transparent PNG image
plt.savefig('transparent_Accgraph.png', transparent=True)

# Display the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
splits = ['80-20', '70-30', '60-40', '40-60', '30-70', '20-80', '10-90', '5-95','UndSamp']
models = ['Gradient', 'RandomF', 'Decision', 'KNN', 'Logistic', 'XGBoost']
mcc_values = {
    'Gradient': [0.25583845, 0.25855086, 0.26912568, 0.264360217, 0.27677706, 0.26895602, 0.2754161, 0.28453465, 0.2515811],
    'RandomF': [0.79872482, 0.78953970, 0.78766553, 0.7687980406, 0.75324092, 0.73993844, 0.7124904, 0.67457691, 0.2966095],
    'Decision': [0.8289679, 0.82522920, 0.81451821, 0.793151803, 0.7813968, 0.75185841, 0.6972964, 0.64280858, 0.30253104],
    'KNN': [0.42535741, 0.42446732, 0.41674394, 0.39404986, 0.3758015, 0.36393166, 0.3416583, 0.30380058, 0.1391211],
    'Logistic': [0.10412612, 0.11618447, 0.1184138, 0.11657375, 0.12788284, 0.1197216, 0.1134896, 0.1096043, 0.0982775],
    'XGBoost': [0.63919853, 0.6579190, 0.64885698, 0.6532424, 0.6972050, 0.6728590, 0.6772991, 0.6743735, 0.35242841]
}

# Set colors for each model
colors = ['red', 'blue', 'green', 'orange', 'purple', 'violet']

# Create the figure and axis
fig, ax = plt.subplots()

# Plot the data
for i, model in enumerate(models):
    ax.plot(splits, mcc_values[model], label=model, color=colors[i % len(colors)])

# Set the y-axis label
ax.set_ylabel('MCC')
ax.set_xlabel('Data')
# Set the title
ax.set_title('MCC for Different Splits and Models')

# Set the legend
ax.legend()

# Set the background of the plot to be transparent
ax.patch.set_alpha(0)

# Set the transparency of the grid lines
ax.grid(alpha=0.2)

# Save the plot as a transparent PNG image
plt.savefig('transparent_MCCgraph.png', transparent=True)
# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
splits = ['80-20', '70-30', '60-40', '40-60', '30-70', '20-80', '10-90', '5-95', 'UndSamp']
models = ['Gradient', 'RandomF', 'Decision', 'KNN', 'Logistic', 'XGBoost']
f1_values = {
    'Gradient': [0.1254325, 0.128051, 0.13801617, 0.133344240, 0.1455791, 0.138234144, 0.14451072, 0.15368946, 0.06464517],
    'RandomF': [0.7866598, 0.776399, 0.77546908, 0.75499958, 0.73894575, 0.7248192, 0.69821592, 0.6580754303, 0.1641093],
    'Decision': [0.8197064, 0.816290, 0.80469859, 0.780284738, 0.7681128, 0.73682938, 0.67771658, 0.62040393, 0.1703386],
    'KNN': [0.3316157, 0.33035037, 0.32010928, 0.29357058, 0.27233429, 0.25781577, 0.23311957, 0.19288421, 0.0417808],
    'Logistic': [0.0268509, 0.032423, 0.03340304, 0.032462280, 0.03797184, 0.03382176, 0.03085120, 0.029049368, 0.02432354],
    'XGBoost': [0.58238379, 0.607044, 0.59594095, 0.601784165, 0.65755320, 0.628046421, 0.63572594, 0.634358260, 0.22304986]
}

# Set colors for each model
colors = ['red', 'blue', 'green', 'orange', 'purple', 'violet']

# Create the figure and axis
fig, ax = plt.subplots()

# Plot the data
for i, model in enumerate(models):
    ax.plot(splits, f1_values[model], label=model, color=colors[i % len(colors)])

# Set the y-axis label
ax.set_ylabel('F1 Score')
ax.set_xlabel('Data')
# Set the title
ax.set_title('F1 Score for Different Splits and Models')

# Set the legend
ax.legend()
# Set the background of the plot to be transparent
ax.patch.set_alpha(0)

# Set the transparency of the grid lines
ax.grid(alpha=0.2)

# Save the plot as a transparent PNG image
plt.savefig('transparent_F1graph.png', transparent=True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
splits = ['80-20', '70-30', '60-40', '40-60', '30-70', '20-80', '10-90', '5-95', 'UndSamp']
models = ['Gradient', 'RandomF', 'Decision', 'KNN', 'Logistic', 'XGBoost']
precision_values = {
    'Gradient': [0.066932, 0.06843235, 0.07416388, 0.071461974, 0.07856426, 0.074306289, 0.07795418, 0.08334235, 0.06464517],
    'RandomF': [0.669410, 0.65590484, 0.65860962, 0.63400138, 0.6176949, 0.6022022, 0.58084476, 0.53807973, 0.0894142],
    'Decision': [0.712204, 0.71059038, 0.69560365, 0.66046511, 0.64778676, 0.613357473, 0.54744282, 0.49050844, 0.0931415],
    'KNN': [0.203570, 0.20258580, 0.19482506, 0.1758011, 0.16095253, 0.15088063, 0.1344341, 0.108619016, 0.0213527],
    'Logistic': [0.013631, 0.0165113, 0.01701823, 0.0165298, 0.01939115, 0.017232789, 0.01569426, 0.01476315, 0.0123314],
    'XGBoost': [0.411870, 0.43753399, 0.42645893, 0.43265633, 0.49282379, 0.461549395, 0.4719947, 0.472926231, 0.125553]
}

# Set colors for each model
colors = ['red', 'blue', 'green', 'orange', 'purple', 'violet']

# Create the figure and axis
fig, ax = plt.subplots()

# Plot the data
for i, model in enumerate(models):
    ax.plot(splits, precision_values[model], label=model, color=colors[i % len(colors)])

# Set the y-axis label
ax.set_ylabel('Precision')
ax.set_xlabel('Data')
# Set the title
ax.set_title('Precision for Different Splits and Models')

# Set the legend
ax.legend()
# Set the background of the plot to be transparent
ax.patch.set_alpha(0)

# Set the transparency of the grid lines
ax.grid(alpha=0.2)

# Save the plot as a transparent PNG image
plt.savefig('transparent_Precisiongraph.png', transparent=True)

# Show the plot
plt.tight_layout()
plt.show()
